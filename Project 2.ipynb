# %% [markdown]
# ### Hello, welcome to another lesson on python and the data science libraries ( Numpy, Pandas and Matplotlib). This is another dummy dataset that i worked on as i learned and grow on this career path. I want you to connect deeply with these dataset and feel encouraged about what you're doing. We all do it a little poorly until we get better. That's why i share my journey and my growth process.
#
# ## So, Let's get started !!!

# %% [markdown]
# ### The first step is to import numpy and pandas libraries and load in the dataset. I also read the first 10 lines of the imported data as well as the last 10 using the .head() and .tail() functions respectively. This is for me to have an idea of wha my Dataset looks like.

# %%
import numpy as np
import pandas as pd
filez = pd.read_excel("Excursion Portfolio.xls")
filez.head(10)
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3 Unnamed: 4  \
# 0         NaN         NaN         NaN         NaN        NaN
# 1         NaN         NaN         NaN         NaN        NaN
# 2         NaN         NaN         NaN         NaN        NaN
# 3         NaN         NaN         NaN         NaN        NaN
# 4         NaN         NaN         NaN         NaN        S/N
# 5         NaN         NaN         NaN         NaN        NaN
# 6         NaN         NaN         NaN         NaN          1
# 7         NaN         NaN         NaN         NaN          2
# 8         NaN         NaN         NaN         NaN          3
# 9         NaN         NaN         NaN         NaN          4
#
#              Unnamed: 5 Unnamed: 6   Unnamed: 7   Unnamed: 8 Unnamed: 9  \
# 0                   NaN        NaN          NaN          NaN        NaN
# 1                   NaN        NaN          NaN          NaN        NaN
# 2                   NaN        NaN          NaN          NaN        NaN
# 3                   NaN        NaN          NaN          NaN        NaN
# 4                  Name     Status  Amount Paid      T-shirt        NaN
# 5                   NaN        NaN          NaN         Type     Amount
# 6    Victor T. Na'Allah     Member        12000  Long Sleeve       2500
# 7        Olajide Mattew     Member        12000  Long Sleeve       2500
# 8     Abel Modu Timothy     Member        12000  Long Sleeve       2500
# 9  Egwim Jones Udojuaku     Member        12000  Long Sleeve       2500
#
#   Unnamed: 10
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4    Comments
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN

# %%
filez.tail(10)
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3                Unnamed: 4  \
# 48         NaN         NaN         NaN         NaN                        43
# 49         NaN         NaN         NaN         NaN                        44
# 50         NaN         NaN         NaN         NaN                        45
# 51         NaN         NaN         NaN         NaN                        46
# 52         NaN         NaN         NaN         NaN                        47
# 53         NaN         NaN         NaN         NaN                        48
# 54         NaN         NaN         NaN         NaN                        49
# 55         NaN         NaN         NaN         NaN                     TOTAL
# 56         NaN         NaN         NaN         NaN                       NaN
# 57         NaN         NaN         NaN         NaN  Total Members Registered
#
#                   Unnamed: 5 Unnamed: 6 Unnamed: 7    Unnamed: 8 Unnamed: 9  \
# 48          Shekinah Ajibola     Member      12000   Long Sleeve       2500
# 49               Adanu David     Member       9000           NIL        NIL
# 50               Oche Muscle     Member       9500           NIL        NIL
# 51           Ocheje Jeremiah     Member      12000  Short Sleeve       2100
# 52  Oguntowo Basit Ifedolapo     Member      12000           NaN        NaN
# 53             Simeon Iganga     Member      12000           NaN        NaN
# 54        Caleb Onuoja Aaron    Ex-Exco       8000           NaN        NaN
# 55                       NaN        NaN     537500           NaN      80700
# 56                       NaN        NaN        NaN           NaN        NaN
# 57                       NaN        NaN         49           NaN        NaN
#
#    Unnamed: 10
# 48         NaN
# 49         NaN
# 50         NaN
# 51         NaN
# 52         NaN
# 53   100 Level
# 54         NaN
# 55         NaN
# 56         NaN
# 57         NaN

# %% [markdown]
# ### I also checked other properties of the dataset which includes its shape size dimension and the data types respectively

# %%
filez.shape
# Out:
# (58, 11)

# %%
filez.size
# Out:
# 638

# %%
filez.ndim
# Out:
# 2

# %%
filez.dtypes
# Out:
# Unnamed: 0     float64
# Unnamed: 1     float64
# Unnamed: 2     float64
# Unnamed: 3     float64
# Unnamed: 4      object
# Unnamed: 5      object
# Unnamed: 6      object
# Unnamed: 7      object
# Unnamed: 8      object
# Unnamed: 9      object
# Unnamed: 10     object
# dtype: object

# %% [markdown]
# ### Next, i renamed the columns of the dataset to make it more relatable. And after that i deleted the columns that contains unrelevant information ( the columns that contained "nan" in all its rows)

# %%
filez.columns = ['COL1','COL2','COL3','COL4','S/N','NAME','STATUS','AMOUNT_PAID','TSHIRT_TYPE','TSHIRT_AMOUNT','COMMENTS']

# %%
filez.head(15)
# Out:
#     COL1  COL2  COL3  COL4  S/N                         NAME  STATUS  \
# 0    NaN   NaN   NaN   NaN  NaN                          NaN     NaN
# 1    NaN   NaN   NaN   NaN  NaN                          NaN     NaN
# 2    NaN   NaN   NaN   NaN  NaN                          NaN     NaN
# 3    NaN   NaN   NaN   NaN  NaN                          NaN     NaN
# 4    NaN   NaN   NaN   NaN  S/N                         Name  Status
# 5    NaN   NaN   NaN   NaN  NaN                          NaN     NaN
# 6    NaN   NaN   NaN   NaN    1           Victor T. Na'Allah  Member
# 7    NaN   NaN   NaN   NaN    2               Olajide Mattew  Member
# 8    NaN   NaN   NaN   NaN    3            Abel Modu Timothy  Member
# 9    NaN   NaN   NaN   NaN    4         Egwim Jones Udojuaku  Member
# 10   NaN   NaN   NaN   NaN    5  Nwachukwu Emmanuel Benedict  Member
# 11   NaN   NaN   NaN   NaN    6                Adole John A.  Member
# 12   NaN   NaN   NaN   NaN    7         Faleti Ayodeji Peter  Member
# 13   NaN   NaN   NaN   NaN    8      Ayantoye Ridwan Ayomide  Member
# 14   NaN   NaN   NaN   NaN    9         Marvellous  T. Isaac  Member
#
#     AMOUNT_PAID   TSHIRT_TYPE TSHIRT_AMOUNT  COMMENTS
# 0           NaN           NaN           NaN       NaN
# 1           NaN           NaN           NaN       NaN
# 2           NaN           NaN           NaN       NaN
# 3           NaN           NaN           NaN       NaN
# 4   Amount Paid       T-shirt           NaN  Comments
# 5           NaN          Type        Amount       NaN
# 6         12000   Long Sleeve          2500       NaN
# 7         12000   Long Sleeve          2500       NaN
# 8         12000   Long Sleeve          2500       NaN
# 9         12000   Long Sleeve          2500       NaN
# 10        12000   Long Sleeve          2500       NaN
# 11        12000  Short Sleeve          2100       NaN
# 12        12000  Short Sleeve          2100       NaN
# 13        12000           NaN           NaN       NaN
# 14        12000  Short Sleeve          2100       NaN

# %%
filez1 = filez.drop(['COL1','COL2','COL3','COL4','S/N','COMMENTS'], axis =1)

# %%
filez1.head(15)
# Out:
#                            NAME  STATUS  AMOUNT_PAID   TSHIRT_TYPE  \
# 0                           NaN     NaN          NaN           NaN
# 1                           NaN     NaN          NaN           NaN
# 2                           NaN     NaN          NaN           NaN
# 3                           NaN     NaN          NaN           NaN
# 4                          Name  Status  Amount Paid       T-shirt
# 5                           NaN     NaN          NaN          Type
# 6            Victor T. Na'Allah  Member        12000   Long Sleeve
# 7                Olajide Mattew  Member        12000   Long Sleeve
# 8             Abel Modu Timothy  Member        12000   Long Sleeve
# 9          Egwim Jones Udojuaku  Member        12000   Long Sleeve
# 10  Nwachukwu Emmanuel Benedict  Member        12000   Long Sleeve
# 11                Adole John A.  Member        12000  Short Sleeve
# 12         Faleti Ayodeji Peter  Member        12000  Short Sleeve
# 13      Ayantoye Ridwan Ayomide  Member        12000           NaN
# 14         Marvellous  T. Isaac  Member        12000  Short Sleeve
#
#    TSHIRT_AMOUNT
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5         Amount
# 6           2500
# 7           2500
# 8           2500
# 9           2500
# 10          2500
# 11          2100
# 12          2100
# 13           NaN
# 14          2100

# %%
filez1.tail(10)
# Out:
#                         NAME   STATUS AMOUNT_PAID   TSHIRT_TYPE TSHIRT_AMOUNT
# 48          Shekinah Ajibola   Member       12000   Long Sleeve          2500
# 49               Adanu David   Member        9000           NIL           NIL
# 50               Oche Muscle   Member        9500           NIL           NIL
# 51           Ocheje Jeremiah   Member       12000  Short Sleeve          2100
# 52  Oguntowo Basit Ifedolapo   Member       12000           NaN           NaN
# 53             Simeon Iganga   Member       12000           NaN           NaN
# 54        Caleb Onuoja Aaron  Ex-Exco        8000           NaN           NaN
# 55                       NaN      NaN      537500           NaN         80700
# 56                       NaN      NaN         NaN           NaN           NaN
# 57                       NaN      NaN          49           NaN           NaN

# %% [markdown]
# ### Next , i dropped all the rows which contains "nan" all across the dataset or unrelevant data

# %%
filez2 = filez1.drop([ 0,1,2,3,4,5,55,56,57])

# %%
filez2.head(10)
# Out:
#                            NAME  STATUS AMOUNT_PAID   TSHIRT_TYPE  \
# 6            Victor T. Na'Allah  Member       12000   Long Sleeve
# 7                Olajide Mattew  Member       12000   Long Sleeve
# 8             Abel Modu Timothy  Member       12000   Long Sleeve
# 9          Egwim Jones Udojuaku  Member       12000   Long Sleeve
# 10  Nwachukwu Emmanuel Benedict  Member       12000   Long Sleeve
# 11                Adole John A.  Member       12000  Short Sleeve
# 12         Faleti Ayodeji Peter  Member       12000  Short Sleeve
# 13      Ayantoye Ridwan Ayomide  Member       12000           NaN
# 14         Marvellous  T. Isaac  Member       12000  Short Sleeve
# 15    Shenge Raphael Saarshatar  Member       12000  Short Sleeve
#
#    TSHIRT_AMOUNT
# 6           2500
# 7           2500
# 8           2500
# 9           2500
# 10          2500
# 11          2100
# 12          2100
# 13           NaN
# 14          2100
# 15          2100

# %%
filez2.tail(10)
# Out:
#                         NAME   STATUS AMOUNT_PAID   TSHIRT_TYPE TSHIRT_AMOUNT
# 45       Daleng Elisha Nandi   Member        9000           NaN           NaN
# 46    Ukande Aondongu Cephas   Member       12000   Long Sleeve          2500
# 47       De-Gold David Tarki   Member       12000           NaN           NaN
# 48          Shekinah Ajibola   Member       12000   Long Sleeve          2500
# 49               Adanu David   Member        9000           NIL           NIL
# 50               Oche Muscle   Member        9500           NIL           NIL
# 51           Ocheje Jeremiah   Member       12000  Short Sleeve          2100
# 52  Oguntowo Basit Ifedolapo   Member       12000           NaN           NaN
# 53             Simeon Iganga   Member       12000           NaN           NaN
# 54        Caleb Onuoja Aaron  Ex-Exco        8000           NaN           NaN

# %% [markdown]
# ### Next, I made the "NAME" column the Index label. And i dropped the column after this step
#
# #### Note that this step of setting a column as an index can also be achieved by using the "set_index()" method will you'll learn in later lessons

# %%
filez2.index = filez2["NAME"]

# %%
filez2.head()
# Out:
#                                                     NAME  STATUS AMOUNT_PAID  \
# NAME
# Victor T. Na'Allah                    Victor T. Na'Allah  Member       12000
# Olajide Mattew                            Olajide Mattew  Member       12000
# Abel Modu Timothy                      Abel Modu Timothy  Member       12000
# Egwim Jones Udojuaku                Egwim Jones Udojuaku  Member       12000
# Nwachukwu Emmanuel Benedict  Nwachukwu Emmanuel Benedict  Member       12000
#
#                              TSHIRT_TYPE TSHIRT_AMOUNT
# NAME
# Victor T. Na'Allah           Long Sleeve          2500
# Olajide Mattew               Long Sleeve          2500
# Abel Modu Timothy            Long Sleeve          2500
# Egwim Jones Udojuaku         Long Sleeve          2500
# Nwachukwu Emmanuel Benedict  Long Sleeve          2500

# %%
filez3 = filez2.drop("NAME", axis = "columns")

# %%
filez3.head()
# Out:
#                              STATUS AMOUNT_PAID  TSHIRT_TYPE TSHIRT_AMOUNT
# NAME
# Victor T. Na'Allah           Member       12000  Long Sleeve          2500
# Olajide Mattew               Member       12000  Long Sleeve          2500
# Abel Modu Timothy            Member       12000  Long Sleeve          2500
# Egwim Jones Udojuaku         Member       12000  Long Sleeve          2500
# Nwachukwu Emmanuel Benedict  Member       12000  Long Sleeve          2500

# %%
filez3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49 entries, Victor T. Na'Allah to Caleb Onuoja Aaron
# Data columns (total 4 columns):
# STATUS           49 non-null object
# AMOUNT_PAID      48 non-null object
# TSHIRT_TYPE      39 non-null object
# TSHIRT_AMOUNT    39 non-null object
# dtypes: object(4)
# memory usage: 980.0+ bytes

# %% [markdown]
# ### Next i checked if there are null values on the Dataset and where excatly they are located

# %%
filez3.isnull().sum()
# Out:
# STATUS            0
# AMOUNT_PAID       1
# TSHIRT_TYPE      10
# TSHIRT_AMOUNT    10
# dtype: int64

# %%
filez3["AMOUNT_PAID"].head(10)
# Out:
# NAME
# Victor T. Na'Allah             12000
# Olajide Mattew                 12000
# Abel Modu Timothy              12000
# Egwim Jones Udojuaku           12000
# Nwachukwu Emmanuel Benedict    12000
# Adole John A.                  12000
# Faleti Ayodeji Peter           12000
# Ayantoye Ridwan Ayomide        12000
# Marvellous  T. Isaac           12000
# Shenge Raphael Saarshatar      12000
# Name: AMOUNT_PAID, dtype: object

# %% [markdown]
# ### I filled the null values in the "AMOUNT PAID" column with 0, and set inplace to be True. And i checked to confirm if the change has been effected

# %%
filez3["AMOUNT_PAID"].fillna(0, inplace = True)

# %%
filez3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49 entries, Victor T. Na'Allah to Caleb Onuoja Aaron
# Data columns (total 4 columns):
# STATUS           49 non-null object
# AMOUNT_PAID      49 non-null int64
# TSHIRT_TYPE      39 non-null object
# TSHIRT_AMOUNT    39 non-null object
# dtypes: int64(1), object(3)
# memory usage: 1.1+ KB

# %%
filez3["TSHIRT_TYPE"].head()
# Out:
# NAME
# Victor T. Na'Allah             Long Sleeve
# Olajide Mattew                 Long Sleeve
# Abel Modu Timothy              Long Sleeve
# Egwim Jones Udojuaku           Long Sleeve
# Nwachukwu Emmanuel Benedict    Long Sleeve
# Name: TSHIRT_TYPE, dtype: object

# %% [markdown]
# ### If filled the null values contained in the "T-SHIRT TYPE" column with Long Sleeve and set inplace to True.
# ### I replaced the null values contained in "T-SHIRT AMOUNT" accordingly
#
# #### I also checked to comfirm the change has been effected

# %%
filez3["TSHIRT_TYPE"].fillna("Long Sleeve", inplace = True)

# %%
filez3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49 entries, Victor T. Na'Allah to Caleb Onuoja Aaron
# Data columns (total 4 columns):
# STATUS           49 non-null object
# AMOUNT_PAID      49 non-null int64
# TSHIRT_TYPE      49 non-null object
# TSHIRT_AMOUNT    39 non-null object
# dtypes: int64(1), object(3)
# memory usage: 1.1+ KB

# %%
filez3["TSHIRT_AMOUNT"].head()
# Out:
# NAME
# Victor T. Na'Allah             2500
# Olajide Mattew                 2500
# Abel Modu Timothy              2500
# Egwim Jones Udojuaku           2500
# Nwachukwu Emmanuel Benedict    2500
# Name: TSHIRT_AMOUNT, dtype: object

# %%
filez3["TSHIRT_AMOUNT"].fillna(2500, inplace = True)

# %%
filez3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49 entries, Victor T. Na'Allah to Caleb Onuoja Aaron
# Data columns (total 4 columns):
# STATUS           49 non-null object
# AMOUNT_PAID      49 non-null int64
# TSHIRT_TYPE      49 non-null object
# TSHIRT_AMOUNT    49 non-null object
# dtypes: int64(1), object(3)
# memory usage: 1.1+ KB

# %%
filez3
# Out:
#                                                 STATUS  AMOUNT_PAID  \
# NAME
# Victor T. Na'Allah                              Member        12000
# Olajide Mattew                                  Member        12000
# Abel Modu Timothy                               Member        12000
# Egwim Jones Udojuaku                            Member        12000
# Nwachukwu Emmanuel Benedict                     Member        12000
# Adole John A.                                   Member        12000
# Faleti Ayodeji Peter                            Member        12000
# Ayantoye Ridwan Ayomide                         Member        12000
# Marvellous  T. Isaac                            Member        12000
# Shenge Raphael Saarshatar                       Member        12000
# Reuben O.Enoch                                  Member        12000
# Mercy Ajayi                                     Member        12000
# Michael Kpoco                                  Ex-Exco         7000
# Saad                                            Member        12000
# Terzungwe Caleb                                Ex-Exco         5000
# Faith                                           Member        12000
# Gonet Zion                                      Member        12000
# Hawwau Adeboyin Adeyemo\nFor => Jubrin Omeiza   Member        12000
# Nicholas Otonoku                                Member        12000
# Timothy Ignitus Agbor                           Member        12000
# Madumche Chidibere                              Member        12000
# Nwokocha Ethelbert                             Ex-Exco         8000
# Effiong Ubon Alasi                              Member        12000
# Daniel Overcomer                                Member        12000
# Aguwa Wisdom                                    Member        12000
# Ganiyu Mujeeb                                   Member        12000
# Hezekiel Joel                                   Member        12000
# Shitu Mustapha Ibrahim                          Member        12000
# Orogu Francis Israel                            Member        12000
# Agha Elizabeth                                  Member        12000
# Muhammed Zainab                                 Member        12000
# Isaac Priscilla                                 Member        12000
# Paul Elizabeth Ladi                             Member        12000
# Omaji Samuel Owoicho                           Ex-Exco         8000
# Esinome Abraham                                 Member        12000
# Umeh Audu Ayigba                                Member        12000
# Sarah Kauna Edoja                               Member         8000
# Ibrahim Hussein Chado                           Member        10000
# Fatima Ganiyu                                   Member            0
# Daleng Elisha Nandi                             Member         9000
# Ukande Aondongu Cephas                          Member        12000
# De-Gold David Tarki                             Member        12000
# Shekinah Ajibola                                Member        12000
# Adanu David                                     Member         9000
# Oche Muscle                                     Member         9500
# Ocheje Jeremiah                                 Member        12000
# Oguntowo Basit Ifedolapo                        Member        12000
# Simeon Iganga                                   Member        12000
# Caleb Onuoja Aaron                             Ex-Exco         8000
#
#                                                 TSHIRT_TYPE TSHIRT_AMOUNT
# NAME
# Victor T. Na'Allah                              Long Sleeve          2500
# Olajide Mattew                                  Long Sleeve          2500
# Abel Modu Timothy                               Long Sleeve          2500
# Egwim Jones Udojuaku                            Long Sleeve          2500
# Nwachukwu Emmanuel Benedict                     Long Sleeve          2500
# Adole John A.                                  Short Sleeve          2100
# Faleti Ayodeji Peter                           Short Sleeve          2100
# Ayantoye Ridwan Ayomide                         Long Sleeve          2500
# Marvellous  T. Isaac                           Short Sleeve          2100
# Shenge Raphael Saarshatar                      Short Sleeve          2100
# Reuben O.Enoch                                  Long Sleeve          2500
# Mercy Ajayi                                     Long Sleeve          2500
# Michael Kpoco                                  Short Sleeve          2100
# Saad                                            Long Sleeve          2500
# Terzungwe Caleb                                Short Sleeve          2100
# Faith                                           Long Sleeve          2500
# Gonet Zion                                      Long Sleeve          2500
# Hawwau Adeboyin Adeyemo\nFor => Jubrin Omeiza   Long Sleeve          2500
# Nicholas Otonoku                               Short Sleeve          2100
# Timothy Ignitus Agbor                           Long Sleeve          2500
# Madumche Chidibere                              Long Sleeve          2500
# Nwokocha Ethelbert                             Short Sleeve          2100
# Effiong Ubon Alasi                              Long Sleeve          2500
# Daniel Overcomer                               Short Sleeve          2100
# Aguwa Wisdom                                    Long Sleeve          2500
# Ganiyu Mujeeb                                   Long Sleeve          2500
# Hezekiel Joel                                   Long Sleeve          2500
# Shitu Mustapha Ibrahim                          Long Sleeve          2500
# Orogu Francis Israel                           Short Sleeve          2100
# Agha Elizabeth                                 Short Sleeve          2100
# Muhammed Zainab                                 Long Sleeve          2500
# Isaac Priscilla                                Short Sleeve          2100
# Paul Elizabeth Ladi                            Short Sleeve          2100
# Omaji Samuel Owoicho                           Short Sleeve          2100
# Esinome Abraham                                Short Sleeve          2100
# Umeh Audu Ayigba                               Short Sleeve          2100
# Sarah Kauna Edoja                               Long Sleeve          2500
# Ibrahim Hussein Chado                                   NIL           NIL
# Fatima Ganiyu                                           NIL           NIL
# Daleng Elisha Nandi                             Long Sleeve          2500
# Ukande Aondongu Cephas                          Long Sleeve          2500
# De-Gold David Tarki                             Long Sleeve          2500
# Shekinah Ajibola                                Long Sleeve          2500
# Adanu David                                             NIL           NIL
# Oche Muscle                                             NIL           NIL
# Ocheje Jeremiah                                Short Sleeve          2100
# Oguntowo Basit Ifedolapo                        Long Sleeve          2500
# Simeon Iganga                                   Long Sleeve          2500
# Caleb Onuoja Aaron                              Long Sleeve          2500

# %%
filez3["TSHIRT_TYPE"].unique()
# Out:
# array(['Long Sleeve', 'Short Sleeve', 'NIL'], dtype=object)

# %%
filez3["TSHIRT_AMOUNT"].unique()
# Out:
# array([2500, 2100, 'NIL'], dtype=object)

# %% [markdown]
# ### Checking the info of the Dataset, it's revealed that there are some values that are wrong. Like "NIL", and they are replaced accordingly using the replace function.
#
# #### Note that this not a null value and requires a different treatment from "nan". If it were to be null values, "dropna" / "fillna" wolud have taken care of it

# %%
filez3["TSHIRT_TYPE"].replace({"NIL" : "No Sleeve"}, inplace = True)

# %%
filez3["TSHIRT_AMOUNT"].replace({"NIL" : 0}, inplace = True)

# %%
filez3
# Out:
#                                                 STATUS  AMOUNT_PAID  \
# NAME
# Victor T. Na'Allah                              Member        12000
# Olajide Mattew                                  Member        12000
# Abel Modu Timothy                               Member        12000
# Egwim Jones Udojuaku                            Member        12000
# Nwachukwu Emmanuel Benedict                     Member        12000
# Adole John A.                                   Member        12000
# Faleti Ayodeji Peter                            Member        12000
# Ayantoye Ridwan Ayomide                         Member        12000
# Marvellous  T. Isaac                            Member        12000
# Shenge Raphael Saarshatar                       Member        12000
# Reuben O.Enoch                                  Member        12000
# Mercy Ajayi                                     Member        12000
# Michael Kpoco                                  Ex-Exco         7000
# Saad                                            Member        12000
# Terzungwe Caleb                                Ex-Exco         5000
# Faith                                           Member        12000
# Gonet Zion                                      Member        12000
# Hawwau Adeboyin Adeyemo\nFor => Jubrin Omeiza   Member        12000
# Nicholas Otonoku                                Member        12000
# Timothy Ignitus Agbor                           Member        12000
# Madumche Chidibere                              Member        12000
# Nwokocha Ethelbert                             Ex-Exco         8000
# Effiong Ubon Alasi                              Member        12000
# Daniel Overcomer                                Member        12000
# Aguwa Wisdom                                    Member        12000
# Ganiyu Mujeeb                                   Member        12000
# Hezekiel Joel                                   Member        12000
# Shitu Mustapha Ibrahim                          Member        12000
# Orogu Francis Israel                            Member        12000
# Agha Elizabeth                                  Member        12000
# Muhammed Zainab                                 Member        12000
# Isaac Priscilla                                 Member        12000
# Paul Elizabeth Ladi                             Member        12000
# Omaji Samuel Owoicho                           Ex-Exco         8000
# Esinome Abraham                                 Member        12000
# Umeh Audu Ayigba                                Member        12000
# Sarah Kauna Edoja                               Member         8000
# Ibrahim Hussein Chado                           Member        10000
# Fatima Ganiyu                                   Member            0
# Daleng Elisha Nandi                             Member         9000
# Ukande Aondongu Cephas                          Member        12000
# De-Gold David Tarki                             Member        12000
# Shekinah Ajibola                                Member        12000
# Adanu David                                     Member         9000
# Oche Muscle                                     Member         9500
# Ocheje Jeremiah                                 Member        12000
# Oguntowo Basit Ifedolapo                        Member        12000
# Simeon Iganga                                   Member        12000
# Caleb Onuoja Aaron                             Ex-Exco         8000
#
#                                                 TSHIRT_TYPE  TSHIRT_AMOUNT
# NAME
# Victor T. Na'Allah                              Long Sleeve           2500
# Olajide Mattew                                  Long Sleeve           2500
# Abel Modu Timothy                               Long Sleeve           2500
# Egwim Jones Udojuaku                            Long Sleeve           2500
# Nwachukwu Emmanuel Benedict                     Long Sleeve           2500
# Adole John A.                                  Short Sleeve           2100
# Faleti Ayodeji Peter                           Short Sleeve           2100
# Ayantoye Ridwan Ayomide                         Long Sleeve           2500
# Marvellous  T. Isaac                           Short Sleeve           2100
# Shenge Raphael Saarshatar                      Short Sleeve           2100
# Reuben O.Enoch                                  Long Sleeve           2500
# Mercy Ajayi                                     Long Sleeve           2500
# Michael Kpoco                                  Short Sleeve           2100
# Saad                                            Long Sleeve           2500
# Terzungwe Caleb                                Short Sleeve           2100
# Faith                                           Long Sleeve           2500
# Gonet Zion                                      Long Sleeve           2500
# Hawwau Adeboyin Adeyemo\nFor => Jubrin Omeiza   Long Sleeve           2500
# Nicholas Otonoku                               Short Sleeve           2100
# Timothy Ignitus Agbor                           Long Sleeve           2500
# Madumche Chidibere                              Long Sleeve           2500
# Nwokocha Ethelbert                             Short Sleeve           2100
# Effiong Ubon Alasi                              Long Sleeve           2500
# Daniel Overcomer                               Short Sleeve           2100
# Aguwa Wisdom                                    Long Sleeve           2500
# Ganiyu Mujeeb                                   Long Sleeve           2500
# Hezekiel Joel                                   Long Sleeve           2500
# Shitu Mustapha Ibrahim                          Long Sleeve           2500
# Orogu Francis Israel                           Short Sleeve           2100
# Agha Elizabeth                                 Short Sleeve           2100
# Muhammed Zainab                                 Long Sleeve           2500
# Isaac Priscilla                                Short Sleeve           2100
# Paul Elizabeth Ladi                            Short Sleeve           2100
# Omaji Samuel Owoicho                           Short Sleeve           2100
# Esinome Abraham                                Short Sleeve           2100
# Umeh Audu Ayigba                               Short Sleeve           2100
# Sarah Kauna Edoja                               Long Sleeve           2500
# Ibrahim Hussein Chado                             No Sleeve              0
# Fatima Ganiyu                                     No Sleeve              0
# Daleng Elisha Nandi                             Long Sleeve           2500
# Ukande Aondongu Cephas                          Long Sleeve           2500
# De-Gold David Tarki                             Long Sleeve           2500
# Shekinah Ajibola                                Long Sleeve           2500
# Adanu David                                       No Sleeve              0
# Oche Muscle                                       No Sleeve              0
# Ocheje Jeremiah                                Short Sleeve           2100
# Oguntowo Basit Ifedolapo                        Long Sleeve           2500
# Simeon Iganga                                   Long Sleeve           2500
# Caleb Onuoja Aaron                              Long Sleeve           2500

# %% [markdown]
# ### The file is ready for analysis, visualization or any other process.
#
#
# ### I checked a few of its properties to double check all I've done.

# %%
filez3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49 entries, Victor T. Na'Allah to Caleb Onuoja Aaron
# Data columns (total 4 columns):
# STATUS           49 non-null object
# AMOUNT_PAID      49 non-null int64
# TSHIRT_TYPE      49 non-null object
# TSHIRT_AMOUNT    49 non-null int64
# dtypes: int64(2), object(2)
# memory usage: 1.3+ KB

# %%
filez3.describe()
# Out:
#         AMOUNT_PAID  TSHIRT_AMOUNT
# count     49.000000      49.000000
# mean   10969.387755    2157.142857
# std     2319.321388     676.387463
# min        0.000000       0.000000
# 25%    12000.000000    2100.000000
# 50%    12000.000000    2500.000000
# 75%    12000.000000    2500.000000
# max    12000.000000    2500.000000

# %%
filez3.shape
# Out:
# (49, 4)

# %%
filez3.size
# Out:
# 196

# %%
filez3.dtypes
# Out:
# STATUS           object
# AMOUNT_PAID       int64
# TSHIRT_TYPE      object
# TSHIRT_AMOUNT     int64
# dtype: object

# %%
filez3.ndim
# Out:
# 2

# %% [markdown]
# ### Now, you can write the file back into a document. In this case, i choose to write it back to an excel file

# %%
filez3.to_excel("ExcurPort Document.xlsx")

# %% [markdown]
# This document has been successfully prepared for analysis.
# And I'm really excited 😁 😊😄 about that.
# It's also been successfully written back to an excel file.
# And that's another giant feat achieved.
# I'll keep the document safe for visualization analysis when I'm done and ready with Matplotlib.
# I thank God for this that I've been able to achieve.
# #ThankfulHeart.
# #GratefulHeart
# #JourneyToGreatAndExtraordinaryFeats.
# #TheBecomingOfAWorldReveredDataScientist
# #TheMakingOfADataAnalyst

# %% [markdown]
# ### This brings this lesson to an end. The best way to learn is by doing, so get started and get practicing. It's only a matter of improved effort and you'd have developed your skills to take on giant projects.

# %% [markdown]
# ### Wishing you Goodspeed and Happy Learning
